# %% [markdown]
# # File gathering testing

# %%
import pandas as pd
import os
path = r'C:\Users\abdul\Documents\GitHub\GeneSweeper_2.0\CSV_files'
extension = '.csv'
files = [file for file in os.listdir(path) if file.endswith(extension)]

# %%
dfs = []
for file in files:
    df = pd.read_csv(os.path.join(path, file), delimiter='\t')
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#                                                 GENE ID  LOCUS TAG  \
# 0            3300066319 assembled Ga0610651_106470_1_93        NaN
# 1           3300066319 assembled Ga0610651_059228_3_419        NaN
# 2         3300066319 assembled Ga0610651_036890_164_529        NaN
# 3         3300066319 assembled Ga0610651_047506_145_483        NaN
# 4           3300066319 assembled Ga0610651_038166_3_524        NaN
# ...                                                 ...        ...
# 760878      3300043246 assembled Ga0435283_117815_3_305        NaN
# 760879      3300043246 assembled Ga0435283_054686_1_465        NaN
# 760880  3300043246 assembled Ga0435283_000101_5656_8052        NaN
# 760881      3300043246 assembled Ga0435283_007286_3_302        NaN
# 760882     3300043246 assembled Ga0435283_011305_1_1095        NaN
#
#                                        PRODUCT NAME       SCAFFOLD ID  \
# 0                              hypothetical protein  Ga0610651_106470
# 1                      AP-1 complex subunit gamma-1  Ga0610651_059228
# 2                              hypothetical protein  Ga0610651_036890
# 3       DNA-directed RNA polymerase II subunit RPB2  Ga0610651_047506
# 4                              hypothetical protein  Ga0610651_038166
# ...                                             ...               ...
# 760878                         hypothetical protein  Ga0435283_117815
# 760879  electron transfer flavoprotein beta subunit  Ga0435283_054686
# 760880                      pyruvate,water dikinase  Ga0435283_000101
# 760881            subtilisin family serine protease  Ga0435283_007286
# 760882                         hypothetical protein  Ga0435283_011305
#
#         GENE SEQ LENGTH  READS COUNT      COVERAGE   MEDIAN  \
# 0                    93            3  1.335065e-09      2.0
# 1                   417           18  1.786490e-09      5.0
# 2                   366           29  3.279299e-09     10.0
# 3                   339           41  5.005510e-09     13.0
# 4                   522           16  1.268568e-09      4.0
# ...                 ...          ...           ...      ...
# 760878              303            3  1.409434e-09      1.0
# 760879              465           13  3.979756e-09      6.0
# 760880             2397          248  1.472820e-08     10.0
# 760881              300            8  3.796075e-09      4.0
# 760882             1095           58  7.540149e-09      7.0
#
#         READS COUNT ANTISENSE  COVERAGE ANTISENSE  MEDIAN ANTISENSE
# 0                           0        0.000000e+00               0.0
# 1                           0        0.000000e+00               0.0
# 2                           0        0.000000e+00               0.0
# 3                           0        0.000000e+00               0.0
# 4                           0        0.000000e+00               0.0
# ...                       ...                 ...               ...
# 760878                      1        4.698112e-10               0.0
# 760879                      5        1.530675e-09               2.0
# 760880                     54        3.206947e-09               3.0
# 760881                      1        4.745094e-10               0.5
# 760882                      8        1.040021e-09               0.0
#
# [760883 rows x 11 columns]
